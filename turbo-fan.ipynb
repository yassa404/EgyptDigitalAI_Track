# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/turbofan/CMAPSSData/RUL_FD002.txt
# /kaggle/input/turbofan/CMAPSSData/test_FD003.txt
# /kaggle/input/turbofan/CMAPSSData/Damage Propagation Modeling.pdf
# /kaggle/input/turbofan/CMAPSSData/readme.txt
# /kaggle/input/turbofan/CMAPSSData/train_FD003.txt
# /kaggle/input/turbofan/CMAPSSData/test_FD004.txt
# /kaggle/input/turbofan/CMAPSSData/train_FD004.txt
# /kaggle/input/turbofan/CMAPSSData/test_FD002.txt
# /kaggle/input/turbofan/CMAPSSData/train_FD001.txt
# /kaggle/input/turbofan/CMAPSSData/train_FD002.txt
# /kaggle/input/turbofan/CMAPSSData/RUL_FD001.txt
# /kaggle/input/turbofan/CMAPSSData/RUL_FD004.txt
# /kaggle/input/turbofan/CMAPSSData/RUL_FD003.txt
# /kaggle/input/turbofan/CMAPSSData/test_FD001.txt

# %%
import keras
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(1234)  
PYTHONHASHSEED = 0
from sklearn import preprocessing
from sklearn.metrics import confusion_matrix, recall_score, precision_score
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Activation
# %matplotlib inline

# %% [markdown]
# ## Add train data

# %%
fd001 = pd.read_csv("/kaggle/input/turbofan/CMAPSSData/train_FD001.txt", sep=" ", header=None)
fd003 = pd.read_csv("/kaggle/input/turbofan/CMAPSSData/train_FD003.txt", sep=" ", header=None)

fd002 = pd.read_csv("/kaggle/input/turbofan/CMAPSSData/train_FD002.txt", sep=" ", header=None)
fd004 = pd.read_csv("/kaggle/input/turbofan/CMAPSSData/train_FD004.txt", sep=" ", header=None)

# إزالة الأعمدة الفارغة الناتجة عن المسافات الزائدة في الملف
fd001 = fd001.dropna(axis=1, how='all')
fd003 = fd003.dropna(axis=1, how='all')
fd002 = fd002.dropna(axis=1, how='all')
fd004 = fd004.dropna(axis=1, how='all')

# %% [markdown]
# ## Test data

# %%
tfd001 = pd.read_csv("/kaggle/input/turbofan/CMAPSSData/test_FD001.txt", sep=" ", header=None)
tfd003 = pd.read_csv("/kaggle/input/turbofan/CMAPSSData/test_FD003.txt", sep=" ", header=None)

tfd002 = pd.read_csv("/kaggle/input/turbofan/CMAPSSData/test_FD002.txt", sep=" ", header=None)
tfd004 = pd.read_csv("/kaggle/input/turbofan/CMAPSSData/test_FD004.txt", sep=" ", header=None)

# إزالة الأعمدة الفارغة الناتجة عن المسافات الزائدة في الملف
tfd001 = tfd001.dropna(axis=1, how='all')
tfd003 = tfd003.dropna(axis=1, how='all')
tfd002 = tfd002.dropna(axis=1, how='all')
tfd004 = tfd004.dropna(axis=1, how='all')

# %%
fd001
# Out:
#         0    1       2       3      4       5       6        7        8   \
# 0        1    1 -0.0007 -0.0004  100.0  518.67  641.82  1589.70  1400.60
# 1        1    2  0.0019 -0.0003  100.0  518.67  642.15  1591.82  1403.14
# 2        1    3 -0.0043  0.0003  100.0  518.67  642.35  1587.99  1404.20
# 3        1    4  0.0007  0.0000  100.0  518.67  642.35  1582.79  1401.87
# 4        1    5 -0.0019 -0.0002  100.0  518.67  642.37  1582.85  1406.22
# ...    ...  ...     ...     ...    ...     ...     ...      ...      ...
# 20626  100  196 -0.0004 -0.0003  100.0  518.67  643.49  1597.98  1428.63
# 20627  100  197 -0.0016 -0.0005  100.0  518.67  643.54  1604.50  1433.58
# 20628  100  198  0.0004  0.0000  100.0  518.67  643.42  1602.46  1428.18
# 20629  100  199 -0.0011  0.0003  100.0  518.67  643.23  1605.26  1426.53
# 20630  100  200 -0.0032 -0.0005  100.0  518.67  643.85  1600.38  1432.14
#
#           9   ...      16       17       18      19    20   21    22     23  \
# ...

# %% [markdown]
# ### Add column_names

# %%
# إضافة أسماء الأعمدة
column_names = [
    "id", "cycle", "setting1", "setting2", "setting3", "s1", "s2", "s3", "s4", "s5", 
    "s6", "s7", "s8", "s9", "s10", "s11", "s12", "s13", "s14", "s15", 
    "s16", "s17", "s18", "s19", "s20", "s21",
]

# تعيين أسماء الأعمدة
fd001.columns = column_names
fd002.columns = column_names
fd003.columns = column_names
fd004.columns = column_names

tfd001.columns = column_names
tfd002.columns = column_names
tfd003.columns = column_names
tfd004.columns = column_names

print("DONE")
# Out:
# DONE

# %%
fd001.describe()
# Out:
#                  id         cycle      setting1      setting2  setting3  \
# count  20631.000000  20631.000000  20631.000000  20631.000000   20631.0
# mean      51.506568    108.807862     -0.000009      0.000002     100.0
# std       29.227633     68.880990      0.002187      0.000293       0.0
# min        1.000000      1.000000     -0.008700     -0.000600     100.0
# 25%       26.000000     52.000000     -0.001500     -0.000200     100.0
# 50%       52.000000    104.000000      0.000000      0.000000     100.0
# 75%       77.000000    156.000000      0.001500      0.000300     100.0
# max      100.000000    362.000000      0.008700      0.000600     100.0
#
#                  s1            s2            s3            s4            s5  \
# count  2.063100e+04  20631.000000  20631.000000  20631.000000  2.063100e+04
# mean   5.186700e+02    642.680934   1590.523119   1408.933782  1.462000e+01
# std    6.537152e-11      0.500053      6.131150      9.000605  3.394700e-12
# ...

# %%
tfd001.describe()
# Out:
#                  id         cycle      setting1      setting2  setting3  \
# count  13096.000000  13096.000000  13096.000000  13096.000000   13096.0
# mean      51.543907     76.836515     -0.000011      0.000004     100.0
# std       28.289423     53.057749      0.002203      0.000294       0.0
# min        1.000000      1.000000     -0.008200     -0.000600     100.0
# 25%       28.000000     33.000000     -0.001500     -0.000200     100.0
# 50%       52.000000     69.000000     -0.000000     -0.000000     100.0
# 75%       76.000000    113.000000      0.001500      0.000300     100.0
# max      100.000000    303.000000      0.007800      0.000700     100.0
#
#                  s1            s2            s3            s4            s5  \
# count  1.309600e+04  13096.000000  13096.000000  13096.000000  1.309600e+04
# mean   5.186700e+02    642.475088   1588.099204   1404.735362  1.462000e+01
# std    6.014263e-11      0.400899      5.003274      6.688309  2.671743e-12
# ...

# %%
fd001.dtypes
# Out:
# id            int64
# cycle         int64
# setting1    float64
# setting2    float64
# setting3    float64
# s1          float64
# s2          float64
# s3          float64
# s4          float64
# s5          float64
# s6          float64
# s7          float64
# s8          float64
# s9          float64
# s10         float64
# s11         float64
# s12         float64
# s13         float64
# s14         float64
# s15         float64
# s16         float64
# s17           int64
# s18           int64
# s19         float64
# s20         float64
# s21         float64
# dtype: object

# %%
fd001.groupby("id")[["cycle"]].count()
# Out:
#      cycle
# id
# 1      192
# 2      287
# 3      179
# 4      189
# 5      269
# ..     ...
# 96     336
# 97     202
# 98     156
# 99     185
# 100    200
#
# [100 rows x 1 columns]

# %%
dftest=fd003
dftest.groupby("id")[["cycle"]].count()
# Out:
#      cycle
# id
# 1      259
# 2      253
# 3      222
# 4      272
# 5      213
# ..     ...
# 96     491
# 97     275
# 98     307
# 99     145
# 100    152
#
# [100 rows x 1 columns]

# %%
dfmerge200 = pd.concat([fd001, dftest], axis=0, ignore_index=True)

# %%
dfmerge200
# Out:
#         id  cycle  setting1  setting2  setting3      s1      s2       s3  \
# 0        1      1   -0.0007   -0.0004     100.0  518.67  641.82  1589.70
# 1        1      2    0.0019   -0.0003     100.0  518.67  642.15  1591.82
# 2        1      3   -0.0043    0.0003     100.0  518.67  642.35  1587.99
# 3        1      4    0.0007    0.0000     100.0  518.67  642.35  1582.79
# 4        1      5   -0.0019   -0.0002     100.0  518.67  642.37  1582.85
# ...    ...    ...       ...       ...       ...     ...     ...      ...
# 45346  200    148   -0.0016   -0.0003     100.0  518.67  643.78  1596.01
# 45347  200    149    0.0034   -0.0003     100.0  518.67  643.29  1596.38
# 45348  200    150   -0.0016    0.0004     100.0  518.67  643.84  1604.53
# 45349  200    151   -0.0023    0.0004     100.0  518.67  643.94  1597.56
# 45350  200    152    0.0000    0.0003     100.0  518.67  643.64  1599.04
#
#             s4     s5  ...     s12      s13      s14     s15   s16  s17   s18  \
# ...

# %%
dfmerge200.groupby("id")[["cycle"]].sum()
# Out:
#       cycle
# id
# 1     18528
# 2     41328
# 3     16110
# 4     17955
# 5     36315
# ..      ...
# 196  120786
# 197   37950
# 198   47278
# 199   10585
# 200   11628
#
# [200 rows x 1 columns]

# %%
# Data Labeling - generate column RUL
rul = pd.DataFrame(dfmerge200.groupby('id')['cycle'].max()).reset_index()
rul.columns = ['id', 'max']
train_df1 = dfmerge200.merge(rul, on=['id'], how='left')
train_df1['RUL'] = train_df1['max'] - train_df1['cycle']
train_df1.drop('max', axis=1, inplace=True)
train_df1
# Out:
#         id  cycle  setting1  setting2  setting3      s1      s2       s3  \
# 0        1      1   -0.0007   -0.0004     100.0  518.67  641.82  1589.70
# 1        1      2    0.0019   -0.0003     100.0  518.67  642.15  1591.82
# 2        1      3   -0.0043    0.0003     100.0  518.67  642.35  1587.99
# 3        1      4    0.0007    0.0000     100.0  518.67  642.35  1582.79
# 4        1      5   -0.0019   -0.0002     100.0  518.67  642.37  1582.85
# ...    ...    ...       ...       ...       ...     ...     ...      ...
# 45346  200    148   -0.0016   -0.0003     100.0  518.67  643.78  1596.01
# 45347  200    149    0.0034   -0.0003     100.0  518.67  643.29  1596.38
# 45348  200    150   -0.0016    0.0004     100.0  518.67  643.84  1604.53
# 45349  200    151   -0.0023    0.0004     100.0  518.67  643.94  1597.56
# 45350  200    152    0.0000    0.0003     100.0  518.67  643.64  1599.04
#
#             s4     s5  ...      s13      s14     s15   s16  s17   s18    s19  \
# ...

# %%
w1 = 30
w0 = 15
train_df1['label1'] = np.where(train_df1['RUL'] <= w1, 1, 0 )
train_df1['label2'] = train_df1['label1']
train_df1.loc[train_df1['RUL'] <= w0, 'label2'] = 2
train_df1
# Out:
#         id  cycle  setting1  setting2  setting3      s1      s2       s3  \
# 0        1      1   -0.0007   -0.0004     100.0  518.67  641.82  1589.70
# 1        1      2    0.0019   -0.0003     100.0  518.67  642.15  1591.82
# 2        1      3   -0.0043    0.0003     100.0  518.67  642.35  1587.99
# 3        1      4    0.0007    0.0000     100.0  518.67  642.35  1582.79
# 4        1      5   -0.0019   -0.0002     100.0  518.67  642.37  1582.85
# ...    ...    ...       ...       ...       ...     ...     ...      ...
# 45346  200    148   -0.0016   -0.0003     100.0  518.67  643.78  1596.01
# 45347  200    149    0.0034   -0.0003     100.0  518.67  643.29  1596.38
# 45348  200    150   -0.0016    0.0004     100.0  518.67  643.84  1604.53
# 45349  200    151   -0.0023    0.0004     100.0  518.67  643.94  1597.56
# 45350  200    152    0.0000    0.0003     100.0  518.67  643.64  1599.04
#
#             s4     s5  ...     s15   s16  s17   s18    s19    s20      s21  \
# ...

# %%
train_df1['cycle_norm'] = train_df1['cycle']
cols_normalize = train_df1.columns.difference(['id','cycle','RUL','label1','label2'])
min_max_scaler = preprocessing.MinMaxScaler()
norm_train_df = pd.DataFrame(min_max_scaler.fit_transform(train_df1[cols_normalize]), 
                             columns=cols_normalize, 
                             index=train_df1.index)
join_df = train_df1[train_df1.columns.difference(cols_normalize)].join(norm_train_df)
train_df1 = join_df.reindex(columns = train_df1.columns)
train_df1.head()
# Out:
#    id  cycle  setting1  setting2  setting3   s1        s2        s3        s4  \
# 0   1      1  0.459770  0.153846       0.0  0.0  0.229508  0.482798  0.365358
# 1   1      2  0.609195  0.230769       0.0  0.0  0.306792  0.523094  0.404780
# 2   1      3  0.252874  0.692308       0.0  0.0  0.353630  0.450295  0.421232
# 3   1      4  0.540230  0.461538       0.0  0.0  0.353630  0.351454  0.385069
# 4   1      5  0.390805  0.307692       0.0  0.0  0.358314  0.352595  0.452584
#
#     s5  ...  s16       s17  s18  s19       s20       s21  RUL  label1  label2  \
# 0  0.0  ...  0.0  0.333333  0.0  0.0  0.538012  0.506912  191       0       0
# 1  0.0  ...  0.0  0.333333  0.0  0.0  0.502924  0.511179  190       0       0
# 2  0.0  ...  0.0  0.166667  0.0  0.0  0.473684  0.437517  189       0       0
# 3  0.0  ...  0.0  0.333333  0.0  0.0  0.432749  0.465071  188       0       0
# 4  0.0  ...  0.0  0.416667  0.0  0.0  0.444444  0.493367  187       0       0
#
#    cycle_norm
# ...

# %%
tfd001
# Out:
#         id  cycle  setting1  setting2  setting3      s1      s2       s3  \
# 0        1      1    0.0023    0.0003     100.0  518.67  643.02  1585.29
# 1        1      2   -0.0027   -0.0003     100.0  518.67  641.71  1588.45
# 2        1      3    0.0003    0.0001     100.0  518.67  642.46  1586.94
# 3        1      4    0.0042    0.0000     100.0  518.67  642.44  1584.12
# 4        1      5    0.0014    0.0000     100.0  518.67  642.51  1587.19
# ...    ...    ...       ...       ...       ...     ...     ...      ...
# 13091  100    194    0.0049    0.0000     100.0  518.67  643.24  1599.45
# 13092  100    195   -0.0011   -0.0001     100.0  518.67  643.22  1595.69
# 13093  100    196   -0.0006   -0.0003     100.0  518.67  643.44  1593.15
# 13094  100    197   -0.0038    0.0001     100.0  518.67  643.26  1594.99
# 13095  100    198    0.0013    0.0003     100.0  518.67  642.95  1601.62
#
#             s4     s5  ...     s12      s13      s14     s15   s16  s17   s18  \
# ...

# %%
tfd003["id"]=tfd003["id"]+100
tfd003
# Out:
#         id  cycle  setting1  setting2  setting3      s1      s2       s3  \
# 0      101      1   -0.0017   -0.0004     100.0  518.67  641.94  1581.93
# 1      101      2    0.0006   -0.0002     100.0  518.67  642.02  1584.86
# 2      101      3    0.0014   -0.0003     100.0  518.67  641.68  1581.78
# 3      101      4    0.0027    0.0001     100.0  518.67  642.20  1584.53
# 4      101      5   -0.0001    0.0001     100.0  518.67  642.46  1589.03
# ...    ...    ...       ...       ...       ...     ...     ...      ...
# 16591  200    243    0.0011   -0.0003     100.0  518.67  643.04  1594.99
# 16592  200    244   -0.0024    0.0002     100.0  518.67  642.47  1591.27
# 16593  200    245   -0.0053    0.0002     100.0  518.67  642.70  1593.81
# 16594  200    246   -0.0006    0.0001     100.0  518.67  642.19  1595.63
# 16595  200    247    0.0023    0.0004     100.0  518.67  643.19  1592.54
#
#             s4     s5  ...     s12      s13      s14     s15   s16  s17   s18  \
# ...

# %%
merged_df = pd.concat([fd001, fd003], axis=0, ignore_index=True)
merged_df
# Out:
#         id  cycle  setting1  setting2  setting3      s1      s2       s3  \
# 0        1      1   -0.0007   -0.0004     100.0  518.67  641.82  1589.70
# 1        1      2    0.0019   -0.0003     100.0  518.67  642.15  1591.82
# 2        1      3   -0.0043    0.0003     100.0  518.67  642.35  1587.99
# 3        1      4    0.0007    0.0000     100.0  518.67  642.35  1582.79
# 4        1      5   -0.0019   -0.0002     100.0  518.67  642.37  1582.85
# ...    ...    ...       ...       ...       ...     ...     ...      ...
# 45346  200    148   -0.0016   -0.0003     100.0  518.67  643.78  1596.01
# 45347  200    149    0.0034   -0.0003     100.0  518.67  643.29  1596.38
# 45348  200    150   -0.0016    0.0004     100.0  518.67  643.84  1604.53
# 45349  200    151   -0.0023    0.0004     100.0  518.67  643.94  1597.56
# 45350  200    152    0.0000    0.0003     100.0  518.67  643.64  1599.04
#
#             s4     s5  ...     s12      s13      s14     s15   s16  s17   s18  \
# ...

# %%
test_df['cycle_norm'] = test_df['cycle']
norm_test_df = pd.DataFrame(min_max_scaler.transform(test_df[cols_normalize]), 
                            columns=cols_normalize, 
                            index=test_df.index)
test_join_df = test_df[test_df.columns.difference(cols_normalize)].join(norm_test_df)
test_df = test_join_df.reindex(columns = test_df.columns)
test_df = test_df.reset_index(drop=True)
test_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-69fb4d19c305> in <cell line: 1>()
# ----> 1 test_df['cycle_norm'] = test_df['cycle']
#       2 norm_test_df = pd.DataFrame(min_max_scaler.transform(test_df[cols_normalize]),
#       3                             columns=cols_normalize,
#       4                             index=test_df.index)
#       5 test_join_df = test_df[test_df.columns.difference(cols_normalize)].join(norm_test_df)
#
# NameError: name 'test_df' is not defined
