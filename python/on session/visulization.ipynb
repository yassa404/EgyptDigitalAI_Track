# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## matplotlip

# %%
x=[1,2,4,5]
y=[1,2,3,4]
plt.figure(figsize=(4,5))
plt.title('simple data')
plt.xlabel('x')
plt.ylabel('y')
plt.plot(x, y, marker='o', linestyle='--',color='red')
plt.show()

# %%
import seaborn as sns
df=sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.plot(df['total_bill'])

# %%
data = df.select_dtypes(include=['number'])
data
# Out:
#      total_bill   tip  size
# 0         16.99  1.01     2
# 1         10.34  1.66     3
# 2         21.01  3.50     3
# 3         23.68  3.31     2
# 4         24.59  3.61     4
# ..          ...   ...   ...
# 239       29.03  5.92     3
# 240       27.18  2.00     2
# 241       22.67  2.00     2
# 242       17.82  1.75     2
# 243       18.78  3.00     2
#
# [244 rows x 3 columns]

# %%
plt.plot(data)

# %%
data.plot()
# Out:
# <Axes: >

# %%
df['total_bill'].plot()
# Out:
# <Axes: >

# %%
plt.figure(figsize=(5,5))
df['total_bill'].plot()
plt.title('total_bill')
plt.xlabel('total_bill')
plt.ylabel('frquence')
plt.figure(figsize=(5,5))
df['tip'].plot()
plt.title('tip')
plt.xlabel('tip')
plt.ylabel('frquence')
# Out:
# Text(0, 0.5, 'frquence')

# %%
plt.figure(figsize=(7,10))
plt.subplot(2,2,1)
df['total_bill'].plot()
plt.title('total_bill')
plt.xlabel('total_bill')
plt.ylabel('frquence')

plt.subplot(2,2,4)
df['tip'].plot()
plt.title('tip')
plt.xlabel('tip')
plt.ylabel('frquence')
# Out:
# Text(0, 0.5, 'frquence')

# %%
plt.figure(figsize=(14,7))
for i in range(1,4):
    plt.subplot(1,3,i)
    plt.plot(data.iloc[:,i-1])
    plt.xlabel (data.columns[i-1])
    plt.ylabel('frquence')

# %% [markdown]
# ## scatter plot

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.scatter (df['total_bill'],df['tip'])
plt.title('relation between totle bill and tip')
plt.xlabel('total_bill')
plt.ylabel('tip')
# Out:
# Text(0, 0.5, 'tip')

# %%
## not logic as size is continouse and totle bill is discrate
plt.scatter (df['size'],df['total_bill'])
plt.title('relation between totle bill and size')
plt.ylabel('total_bill')
plt.xlabel('size')
# Out:
# Text(0.5, 0, 'size')

# %% [markdown]
# ## bar plot

# %%
plt.bar(df['size'],df['total_bill'])
plt.ylabel('total_bill')
plt.xlabel('size')
# Out:
# Text(0.5, 0, 'size')

# %% [markdown]
# ## hist graph
# #### for data distripution
# #### for check outlayer

# %%
plt.hist(df['total_bill'])
# Out:
# (array([ 7., 42., 68., 51., 31., 19., 12.,  7.,  3.,  4.]),
#  array([ 3.07 ,  7.844, 12.618, 17.392, 22.166, 26.94 , 31.714, 36.488,
#         41.262, 46.036, 50.81 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['total_bill'],bins=20)
# Out:
# (array([ 1.,  6., 13., 29., 31., 37., 28., 23., 18., 13., 10.,  9.,  5.,
#          7.,  3.,  4.,  1.,  2.,  3.,  1.]),
#  array([ 3.07 ,  5.457,  7.844, 10.231, 12.618, 15.005, 17.392, 19.779,
#         22.166, 24.553, 26.94 , 29.327, 31.714, 34.101, 36.488, 38.875,
#         41.262, 43.649, 46.036, 48.423, 50.81 ]),
#  <BarContainer object of 20 artists>)

# %%
plt.grid()
plt.hist(df['tip'],bins=20)
# Out:
# (array([14., 27., 55., 24., 41., 25., 20.,  7., 13.,  6.,  4.,  1.,  4.,
#          0.,  1.,  0.,  0.,  1.,  0.,  1.]),
#  array([ 1.  ,  1.45,  1.9 ,  2.35,  2.8 ,  3.25,  3.7 ,  4.15,  4.6 ,
#          5.05,  5.5 ,  5.95,  6.4 ,  6.85,  7.3 ,  7.75,  8.2 ,  8.65,
#          9.1 ,  9.55, 10.  ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# ## boxplot

# %%
plt.boxplot(df['total_bill'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2081223ce00>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2081223d340>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2081223cb60>],
#  'medians': [<matplotlib.lines.Line2D at 0x2081223d790>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2081223d9d0>],
#  'means': []}

# %%
import seaborn as sns

# %%
sns.boxplot(df['total_bill'])
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.boxplot(data=df,x='day',y='total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
import numpy as np
plt.yticks(np.arange(0,55,5))
plt.xticks(rotation=90)
sns.boxplot(df)
# Out:
# <Axes: >
